# %%
import random

class QuizGame:
    def __init__(self):
        self.questions = []
        self.score = 0

    def load_questions(self):
        self.questions = [
            {
                'question': 'What is the capital of France?',
                'options': ['A. London', 'B. Berlin', 'C. Paris', 'D. Rome'],
                'answer': 'C'
            },
            {
                'question': 'What is the largest planet in our solar system?',
                'options': ['A. Mars', 'B. Jupiter', 'C. Saturn', 'D. Earth'],
                'answer': 'B'
            },
            {
                'question': 'The Python programming language is named after which of the following?',
                'options': ['A. A snake', 'B. A bird', 'C. A mammal', 'D. A fish'],
                'answer': 'A'
            },
            {
                'question': 'In which year did World War II end?',
                'options': ['A. 1939', 'B. 1945', 'C. 1950', 'D. 1960'],
                'answer': 'B'
            },
            {
                'question': 'The formula E=mc^2 is associated with whom?',
                'options': ['A. Isaac Newton', 'B. Albert Einstein', 'C. Galileo Galilei', 'D. Nikola Tesla'],
                'answer': 'B'
            }
        ]

    def present_question(self, question):
        print(question['question'])
        for option in question['options']:
            print(option)
        user_answer = input("Your answer: ").upper()
        return user_answer

    def evaluate_answer(self, user_answer, correct_answer):
        if user_answer == correct_answer:
            print("Correct!")
            self.score += 1
        else:
            print(f"Incorrect. The correct answer is {correct_answer}.")

    def play_quiz(self):
        self.load_questions()
        print("Welcome to the Quiz Game!\n")

        for question in self.questions:
            user_answer = self.present_question(question)
            self.evaluate_answer(user_answer, question['answer'])
            print()

        print(f"Quiz completed! Your final score is {self.score}/{len(self.questions)}.")

        play_again = input("Do you want to play again? (yes/no): ").lower()
        if play_again == 'yes':
            self.score = 0
            self.play_quiz()

if __name__ == "__main__":
    quiz_game = QuizGame()
    quiz_game.play_quiz()
# Out:
# Welcome to the Quiz Game!
#
# What is the capital of France?
# A. London
# B. Berlin
# C. Paris
# D. Rome
# Your answer: a
# Incorrect. The correct answer is C.
#
# What is the largest planet in our solar system?
# A. Mars
# B. Jupiter
# C. Saturn
# D. Earth
# Your answer: b
# Correct!
#
# The Python programming language is named after which of the following?
# A. A snake
# B. A bird
# C. A mammal
# D. A fish
# Your answer: a
# Correct!
#
# In which year did World War II end?
# A. 1939
# B. 1945
# C. 1950
# D. 1960
# Your answer: b
# Correct!
#
# The formula E=mc^2 is associated with whom?
# A. Isaac Newton
# B. Albert Einstein
# C. Galileo Galilei
# D. Nikola Tesla
# Your answer: a
# Incorrect. The correct answer is B.
#
# Quiz completed! Your final score is 3/5.
